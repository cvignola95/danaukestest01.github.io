# %% [markdown]
# ---
# title: this is a simple juptyer notebook
# ---

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# ## Introduction
#
# Here is some text

# %%
x = numpy.r_[0:1:.01]
y = numpy.sin(x)
plt.plot(x,y)
